# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Create white noise

# %%
n_turns = 1000
turns = np.arange(n_turns)
T = turns[1] - turns[0]  # sampling interval = 1
fs = 1 / T  # sampling frequency
f = np.linspace(0, 1 / T, n_turns)  # 1/T = frequency

mu, stdPhaseNoise = 0, 0.3
y = np.random.normal(mu, stdPhaseNoise, len(turns))

# %%
plt.plot(turns, y)
plt.xlabel('turns')
plt.ylabel('Noise amplitude (a.u.)')
# Out:
# Text(0, 0.5, 'Noise amplitude (a.u.)')
